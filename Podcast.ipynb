# %% [markdown]
# <a href="https://colab.research.google.com/github/subhasishsahugit/AI_ML/blob/main/Podcast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers accelerate bitsandbytes edge-tts pydub
# !apt-get install -q ffmpeg
print("✅ Setup Done! Ab mahol banega.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 10.1 MB/s eta 0:00:00
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# ✅ Setup Done! Ab mahol banega.

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
